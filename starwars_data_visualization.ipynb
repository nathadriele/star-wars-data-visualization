# %% [markdown]
# <a href="https://colab.research.google.com/github/nathadriele/star-wars-data-visualization/blob/main/starwars_data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dataset_path = '/content/data/star_wars_universe_dataset.csv'

df = pd.read_csv(dataset_path)

df.head()
# Out:
#              Name Species Homeworld      Affiliation First Appearance  \
# 0  Luke Skywalker   Human  Tatooine   Rebel Alliance       A New Hope
# 1     Darth Vader   Human  Tatooine  Galactic Empire       A New Hope
# 2     Leia Organa   Human  Alderaan   Rebel Alliance       A New Hope
# 3        Han Solo   Human  Corellia   Rebel Alliance       A New Hope
# 4  Obi-Wan Kenobi   Human   Stewjon       Jedi Order       A New Hope
#
#               Weapon  Force Sensitive           Rank               Ship  \
# 0            Blaster             True  Bounty Hunter             Y-Wing
# 1            Blaster             True        Padawan             X-Wing
# 2         Vibroblade            False      Sith Lord  Millennium Falcon
# 3         Lightsaber             True  Bounty Hunter             A-Wing
# 4  Thermal Detonator            False    Jedi Master  Millennium Falcon
#
#   Droid Companion  Mission Count Lightsaber Color  Known Languages Allegiance
# 0           IG-88             49             Blue                9     Rebels
# 1           IG-88             90              NaN                6    Neutral
# 2         Chopper             19            Green                6    Neutral
# 3         Chopper             98             Blue                7       Sith
# 4           K-2SO             24             Blue                4    Neutral
